# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshsehrawat/RL/blob/main/Practical%202%20(Part%201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x= np.random.randint(0,50,1000)
print(x)
# Out:
# [37 14  2  9 11 30 32 19  3 12 38 30  6  8 38 17 43 10  2 48  1 41 16 40
#  32 17 13 11  2 37 33  7  6  4  0 21 20 37 17 14  6 46 48 12 44 49 27 14
#  21 23 13 10 34 35 38 49  6 23 12  6 48 10 34  4 32 11 10 37 31 43 30 37
#  37 22  0 38 25 22 44 29 46 46 21 13 31 46 17  2 36 34 31 13 47 18 25 39
#  22  5 23 19 30  4  7 46 34  2  0 27 36 40 31  0 43 43 37 26  0  4  6 24
#  23 27 46 30 41  4 25 29 43  3  2 34 21 43 18 12 24 37  5  0  0  0 13 21
#  37 34 14 45 17 26 25 22 48 20  8 48 10 23 32 40  1 12 40 20 21 21 46 31
#  26 34 46 46 46 49 26 18  5 14 37 15 48 36 19 14 43 25  3 17 19 37  0 16
#   3 16 13 45 24  0 19  7  4 42  4  7 19  5 15 44 33 32 23  6  2 40  5 21
#   3 11 15  3  6 47 11 46 16  4 19 40 37 49  5 15 44 22 10 44 10  6 32 40
#   8  2 31  8 24 30 33 47 30 27 11 36  6 29 49 35  6 40  7 11 26 31 18 46
#  31 13 12  6 31 26 14 13 19 23 20  1 26 20  2 19 23 37 16 35  7 16  4 15
#  43 15 18 20 47 20 35  9 32 24 45  7 25  9 10 36 39 20 18 11 28 34 40 21
# ...

# %%
y= x+np.random.randint(0,10,1000)

print(y)
# Out:
# [44 21  5 13 12 30 39 24  3 13 38 39 14 15 38 21 51 13  8 57  9 41 23 40
#  34 23 21 12  7 41 33 16  6  9  6 30 25 40 22 20  7 52 52 17 49 58 32 15
#  22 31 17 10 37 36 42 53  8 29 13 13 52 17 37  9 41 20 15 39 38 47 31 39
#  41 23  7 45 27 23 45 31 55 50 27 18 38 49 22 11 37 39 33 19 55 22 31 45
#  25  7 30 28 35  7 16 52 40 11  0 28 43 47 36  1 48 52 41 29  9 13  6 30
#  30 34 53 33 45 11 28 36 47  6  4 43 22 43 20 17 27 42 13  9  0  9 22 29
#  40 43 15 45 23 28 31 23 51 26 12 57 19 26 41 45  9 14 43 26 25 23 52 35
#  30 40 49 51 52 58 32 19  9 17 38 18 57 41 19 14 48 33  5 18 28 39  0 22
#   8 19 14 50 25  9 21 15 11 42  4  9 22  8 16 49 38 40 23 13  6 49  5 21
#   7 16 19  9 13 48 11 51 22  5 28 47 42 51  8 18 45 31 11 47 18 15 34 48
#  16  3 33 10 33 31 39 52 36 28 11 36 11 29 55 36 13 44 10 12 30 36 26 53
#  37 20 12 13 37 26 22 19 28 29 28  3 31 22 10 28 23 37 16 44  9 23 10 22
#  44 21 25 29 47 28 39 17 41 31 51 16 32 15 15 43 44 27 21 15 36 36 42 21
# ...

# %%
from ast import increment_lineno
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[1.       , 0.9806033],
#        [0.9806033, 1.       ]])

# %%
x= np.random.randint(0,50,1000)
z= 100-x

# %%
plt.scatter(x,z)
plt.show()

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
import pandas as pd

# %%
df= pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b']= df['a']+ np.random.normal(0,10,1000)
df['c']= 100 - df['a']+ np.random.normal(0,5,1000)
df['d']= np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.825844 -0.942644 -0.006430
# b  0.825844  1.000000 -0.777977 -0.023391
# c -0.942644 -0.777977  1.000000  0.012323
# d -0.006430 -0.023391  0.012323  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
